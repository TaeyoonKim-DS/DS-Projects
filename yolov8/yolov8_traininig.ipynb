# %%
# %cd /home/studio-lab-user/DS-Projects/yolov8/ultralytics
# !rm -rf runs
# Out:
# /home/studio-lab-user/DS-Projects/yolov8/ultralytics

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 7073, done.
# remote: Counting objects: 100% (677/677), done.
# remote: Compressing objects: 100% (368/368), done.
# remote: Total 7073 (delta 343), reused 570 (delta 308), pack-reused 6396
# Receiving objects: 100% (7073/7073), 5.53 MiB | 9.94 MiB/s, done.
# Resolving deltas: 100% (4697/4697), done.

# %%
# !pip install -e ultralytics
# Out:
# Obtaining file:///home/studio-lab-user/DS-Projects/yolov8/ultralytics
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for ultralytics
# ...

# %%
# %cd datasets
# Out:
# /home/studio-lab-user/DS-Projects/yolov8/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SgaLxwdHL2ih3at97c7N")
project = rf.workspace("logodetection-9ixsl").project("7387")
dataset = project.version(1).download("yolov5")
# Out:
# ...
#   Using cached urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentry-sdk 1.19.1 requires urllib3>=1.26.11; python_version >= "3.6", but you have urllib3 1.26.6 which is incompatible.
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to 7387-1 in yolov5pytorch:: 100%|██████████| 160/160 [00:00<00:00, 5899.11it/s]

# %%
# !pip install urllib3 --upgrade
# Out:
# ...
#   Using cached urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.6
#     Uninstalling urllib3-1.26.6:
#       Successfully uninstalled urllib3-1.26.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# roboflow 0.2.4 requires urllib3==1.26.6, but you have urllib3 1.26.15 which is incompatible.
# ...

# %%
# %cd /home/studio-lab-user/DS-Projects/yolov8
# Out:
# /home/studio-lab-user/DS-Projects/yolov8

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data= data.yaml \
epochs=200\
imgsz=224
# Out:
# Ultralytics YOLOv8.0.84 🚀 Python-3.9.10 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# Out:
# /home/studio-lab-user/DS-Projects/yolov8

# %%
# !yolo task=detect \
mode=val \
model=/home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/train2/weights/best.pt \
data= data.yaml
# Out:
# Ultralytics YOLOv8.0.84 🚀 Python-3.9.10 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/valid/lab
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         14         14      0.986      0.714      0.774      0.588
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Speed: 0.1ms preprocess, 3.1ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/val

# %%
# !yolo task=detect \
mode=predict \
model=/home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/train2/weights/best.pt \
conf=0.25 \
source=datasets/7387-1/test/images
# Out:
# Ultralytics YOLOv8.0.84 🚀 Python-3.9.10 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--28-_png.rf.d830501a0dade509739cefa0eee7e446.jpg: 224x224 (no detections), 8.2ms
# image 2/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--29-_png.rf.7a7831e94796598e1fa6aff6f5445a60.jpg: 224x224 4 7387s, 8.2ms
# image 3/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--49-_png.rf.6d343a4fda3ee281737322dc0c0e4c2e.jpg: 224x224 1 7387, 8.2ms
# image 4/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--5-_png.rf.b98fb9cb74910ea13f16acc7e2f6c028.jpg: 224x224 1 7387, 8.2ms
# image 5/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--6-_png.rf.f6d4c1c16394fd85a3955da2507dec7e.jpg: 224x224 1 7387, 8.2ms
# ...

# %%
from ultralytics import YOLO

model = YOLO('/home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/train2/weights/best.pt')
model.predict(
   source='datasets/7387-1/test/images',
   conf=0.25, save_txt=True, save_conf=True
)
# Out:
# image 1/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--28-_png.rf.d830501a0dade509739cefa0eee7e446.jpg: 224x224 (no detections), 8.2ms
# image 2/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--29-_png.rf.7a7831e94796598e1fa6aff6f5445a60.jpg: 224x224 4 7387s, 8.2ms
# image 3/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--49-_png.rf.6d343a4fda3ee281737322dc0c0e4c2e.jpg: 224x224 1 7387, 8.2ms
# image 4/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--5-_png.rf.b98fb9cb74910ea13f16acc7e2f6c028.jpg: 224x224 1 7387, 8.2ms
# image 5/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--6-_png.rf.f6d4c1c16394fd85a3955da2507dec7e.jpg: 224x224 1 7387, 8.2ms
# image 6/9 /home/studio-lab-user/DS-Projects/yolov8/datasets/7387-1/test/images/pos--61-_png.rf.c90fa000a7face19bd169f58864a1201.jpg: 224x224 (no detections), 8.2ms
# ...
