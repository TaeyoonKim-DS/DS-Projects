# %% [markdown]
# ### Yolo v3 Download and Install

# %%
# !git clone https://github.com/ultralytics/yolov3
# !cd yolov3;pip install -qr requirements.txt
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 9946, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 9946 (delta 15), reused 27 (delta 5), pack-reused 9858
# Receiving objects: 100% (9946/9946), 9.37 MiB | 12.02 MiB/s, done.
# Resolving deltas: 100% (6680/6680), done.
#      |████████████████████████████████| 596 kB 12.7 MB/s

# %%
# Download yoloss22
# !wget -O yoloss2.zip https://github.com/ewankim1023/SDLCV/blob/master/yoloss2.zip?raw=true
# Make a directory - under Content
# !mkdir /content/yoloss
# Unzip the yoloss22
# !unzip yoloss2.zip -d /content/yoloss
# Out:
# --2021-11-24 18:53:16--  https://github.com/ewankim1023/SDLCV/blob/master/yoloss2.zip?raw=true
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/ewankim1023/SDLCV/raw/master/yoloss2.zip [following]
# --2021-11-24 18:53:16--  https://github.com/ewankim1023/SDLCV/raw/master/yoloss2.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/ewankim1023/SDLCV/master/yoloss2.zip [following]
# --2021-11-24 18:53:16--  https://media.githubusercontent.com/media/ewankim1023/SDLCV/master/yoloss2.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53177495 (51M) [application/zip]
# Saving to: ‘yoloss2.zip’
#
# yoloss2.zip         100%[===================>]  50.71M   178MB/s    in 0.3s
#
# 2021-11-24 18:53:19 (178 MB/s) - ‘yoloss2.zip’ saved [53177495/53177495]
#
# Archive:  yoloss2.zip
#    creating: /content/yoloss/images/
#    creating: /content/yoloss/images/train/
#   inflating: /content/yoloss/images/train/1.jpg
#   inflating: /content/yoloss/images/train/2 (1).jpg
#   inflating: /content/yoloss/images/train/2.jpg
#   inflating: /content/yoloss/images/train/3 (1).jpg
#   inflating: /content/yoloss/images/train/3.jpg
#   inflating: /content/yoloss/images/train/BARE FIT - Black on White (Vertical roundel)-01.jpg
#   inflating: /content/yoloss/images/train/BARE FIT - Purple on White (with roundel)-01.jpg
#   inflating: /content/yoloss/images/train/Bare+ Purple Package Group Shot.jpg
#   inflating: /content/yoloss/images/train/New Pink-downward-angle - White.jpg
#   inflating: /content/yoloss/images/train/New Pink-Front - White.jpg
#   inflating: /content/yoloss/images/train/New Pink-Upright-Edge - White.jpg
#   inflating: /content/yoloss/images/train/Nude WBG Sticker Book Range Large.jpg
#   inflating: /content/yoloss/images/train/Purple downward angle white small.jpg
#   inflating: /content/yoloss/images/train/Purple front white large.jpg
#   inflating: /content/yoloss/images/train/Purple Upright Edge white medium.jpg
#   inflating: /content/yoloss/images/train/Purple WBG Sticker NoBook Range Small.jpg
#   inflating: /content/yoloss/images/train/SmoothSkin Pure & Bare+ - Festive 3 - Landscape.JPG
#   inflating: /content/yoloss/images/train/White side whiteBG LEDon small.jpg
#   inflating: /content/yoloss/images/train/White top whiteBG LEDon small.jpg
#    creating: /content/yoloss/labels/
#    creating: /content/yoloss/labels/train/
#   inflating: /content/yoloss/labels/train/1.txt
#   inflating: /content/yoloss/labels/train/2 (1).txt
#   inflating: /content/yoloss/labels/train/2.txt
#   inflating: /content/yoloss/labels/train/3 (1).txt
#   inflating: /content/yoloss/labels/train/3.txt
#   inflating: /content/yoloss/labels/train/BARE FIT - Black on White (Vertical roundel)-01.txt
#   inflating: /content/yoloss/labels/train/BARE FIT - Purple on White (with roundel)-01.txt
#   inflating: /content/yoloss/labels/train/Bare+ Purple Package Group Shot.txt
#   inflating: /content/yoloss/labels/train/New Pink-downward-angle - White.txt
#   inflating: /content/yoloss/labels/train/New Pink-Front - White.txt
#   inflating: /content/yoloss/labels/train/New Pink-Upright-Edge - White.txt
#   inflating: /content/yoloss/labels/train/Nude WBG Sticker Book Range Large.txt
#   inflating: /content/yoloss/labels/train/Purple downward angle white small.txt
#   inflating: /content/yoloss/labels/train/Purple front white large.txt
#   inflating: /content/yoloss/labels/train/Purple Upright Edge white medium.txt
#   inflating: /content/yoloss/labels/train/Purple WBG Sticker NoBook Range Small.txt
#   inflating: /content/yoloss/labels/train/SmoothSkin Pure & Bare+ - Festive 3 - Landscape.txt
#  extracting: /content/yoloss/labels/train/White side whiteBG LEDon small.txt
#  extracting: /content/yoloss/labels/train/White top whiteBG LEDon small.txt

# %%
# Weights and Bias
# !pip install wandb

# %% [markdown]
# ### Dataset용 yaml 파일을 생성하고 학습 수행

# %%
# !wget -O /content/yoloss/yoloss.yaml https://raw.githubusercontent.com/Koreanscot/Projects/master/yoloss.yml
# Out:
# --2021-11-24 18:53:20--  https://raw.githubusercontent.com/Koreanscot/Projects/master/yoloss.yml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 135 [text/plain]
# Saving to: ‘/content/yoloss/yoloss.yaml’
#
# /content/yoloss/yol 100%[===================>]     135  --.-KB/s    in 0s
#
# 2021-11-24 18:53:20 (6.79 MB/s) - ‘/content/yoloss/yoloss.yaml’ saved [135/135]

# %%
# Google Drive 접근을 위한 Mount 적용. 
import os, sys 

from google.colab import drive 

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# soft link로 Google Drive Directory 연결. 
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Google Drive 밑에 Directory 생성. 이미 생성 되어 있을 시 오류 발생. 
# !mkdir "/mydrive/ultra_workdir"
# Out:
#  백업파일
# '계약서_(태윤외1).pdf'
# 'Colab Notebooks'
# 'Conveyancercopyofapplicantoffer - 2021-09-03T092944.070.gdoc'
# 'Conveyancercopyofapplicantoffer - 2021-09-03T092944.070.pdf'
#  GraduationCeremony
#  HBR.zip
#  Indical
# 'My Drive'
#  OneDrive_1_29-08-2021.zip
# 'PPT sample.pptx'
#  ultra_workdir
# 'Vaccination Status.pdf'
# 'Wedding Photos'
# mkdir: cannot create directory ‘/mydrive/ultra_workdir’: File exists

# %%
###  batch size는 4, epoch 150. batch size 8 and epoch 300? large epoch is needed. 69 images - not enough. big batch size is not good. 
# !cd /content/yolov3; python train.py --img 640 --batch 8 --epochs 250 --data /content/yoloss/yoloss.yaml --weights yolov3.pt\
    --project=/mydrive/ultra_workdir --name yoloss --exist-ok
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# train: weights=yolov3.pt, cfg=, data=/content/yoloss/yoloss.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=250, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=/mydrive/ultra_workdir, name=yoloss, exist_ok=True, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov3 ✅
# YOLOv3 🚀 v9.6.0-3-gb870de5 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv3 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir /mydrive/ultra_workdir', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov3/releases/download/v9.6.0/yolov3.pt to yolov3.pt...
# 100% 119M/119M [00:01<00:00, 70.9MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     20672  models.common.Bottleneck                [64, 64]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    164608  models.common.Bottleneck                [128, 128]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  8   2627584  models.common.Bottleneck                [256, 256]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  8  10498048  models.common.Bottleneck                [512, 512]
#   9                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#  10                -1  4  20983808  models.common.Bottleneck                [1024, 1024]
#  11                -1  1   5245952  models.common.Bottleneck                [1024, 1024, False]
#  12                -1  1    525312  models.common.Conv                      [1024, 512, [1, 1]]
#  13                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 1]
#  14                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  15                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 1]
#  16                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 8]  1         0  models.common.Concat                    [1]
#  19                -1  1   1377792  models.common.Bottleneck                [768, 512, False]
#  20                -1  1   1312256  models.common.Bottleneck                [512, 512, False]
#  21                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  22                -1  1   1180672  models.common.Conv                      [256, 512, 3, 1]
#  23                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  24                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  25           [-1, 6]  1         0  models.common.Concat                    [1]
#  26                -1  1    344832  models.common.Bottleneck                [384, 256, False]
#  27                -1  2    656896  models.common.Bottleneck                [256, 256, False]
#  28      [27, 22, 15]  1     32310  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 333 layers, 61523734 parameters, 61523734 gradients, 154.9 GFLOPs
#
# Transferred 433/439 items from yolov3.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 72 weight, 75 weight (no decay), 75 bias
# albumentations: version 1.0.3 required by YOLOv3, but version 0.1.12 is currently installed
# train: Scanning '/content/yoloss/labels/train' images and labels...:   0% 0/19 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/PIL/Image.py:2800: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:2800: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning,
# train: Scanning '/content/yoloss/labels/train' images and labels...19 found, 0 missing, 2 empty, 0 corrupted: 100% 19/19 [00:00<00:00, 340.69it/s]
# train: New cache created: /content/yoloss/labels/train.cache
# val: Scanning '/content/yoloss/labels/train.cache' images and labels... 19 found, 0 missing, 2 empty, 0 corrupted: 100% 19/19 [00:00<?, ?it/s]
# Plotting labels to /mydrive/ultra_workdir/yoloss/labels.jpg...
#
# AutoAnchor: 6.25 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /mydrive/ultra_workdir/yoloss
# Starting training for 250 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/249     5.84G    0.1111   0.02982         0         5       640: 100% 3/3 [00:30<00:00, 10.15s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:04<00:00,  2.22s/it]
#                  all         19         20      0.199     0.0995     0.0202    0.00509
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/249     6.78G    0.1137   0.03176         0         5       640: 100% 3/3 [00:20<00:00,  6.68s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:04<00:00,  2.40s/it]
#                  all         19         20      0.178        0.1     0.0183    0.00664
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/249     6.78G    0.1106   0.03041         0         4       640: 100% 3/3 [00:18<00:00,  6.02s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:04<00:00,  2.28s/it]
#                  all         19         20      0.165        0.1     0.0176    0.00727
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/249     6.78G    0.1107   0.02974         0         5       640: 100% 3/3 [00:23<00:00,  7.84s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:04<00:00,  2.18s/it]
#                  all         19         20      0.173        0.1     0.0234    0.00712
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/249     6.78G    0.1072   0.03045         0         8       640: 100% 3/3 [00:17<00:00,  5.70s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:04<00:00,  2.21s/it]
#                  all         19         20      0.163        0.1     0.0238    0.00691
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/249     6.78G    0.1056   0.03104         0         8       640: 100% 3/3 [00:21<00:00,  7.01s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:04<00:00,  2
/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:02<00:00,  1.39s/it]
#                  all         19         20          1          1      0.995      0.654
#
# 250 epochs completed in 2.222 hours.
# Optimizer stripped from /mydrive/ultra_workdir/yoloss/weights/last.pt, 123.6MB
# Optimizer stripped from /mydrive/ultra_workdir/yoloss/weights/best.pt, 123.6MB
#
# Validating /mydrive/ultra_workdir/yoloss/weights/best.pt...
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.7 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 2/2 [00:04<00:00,  2.07s/it]
#                  all         19         20          1          1      0.995      0.654
# Results saved to /mydrive/ultra_workdir/yoloss

# %%
# image 파일 inference 
# !cd /content/yolov3;python detect.py --source /content/yoloss/images/train/1.jpg \
                            --weights /mydrive/ultra_workdir/yoloss/weights/best.pt --conf 0.3 \
                            --project=/content/data/output --name=run_image --exist-ok --line-thickness 3
# Out:
# detect: weights=['/mydrive/ultra_workdir/yoloss/weights/best.pt'], source=/content/yoloss/images/train/1.jpg, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/data/output, name=run_image, exist_ok=True, line_thickness=2, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-3-gb870de5 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.7 GFLOPs
# image 1/1 /content/yoloss/images/train/1.jpg: 640x640 1 Logo, Done. (0.138s)
# Speed: 0.6ms pre-process, 137.5ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/data/output/run_image

# %%
from IPython.display import Image, clear_output 

Image(filename='/content/data/output/run_image/1.jpg', width=800)

# %%
# image 파일 inference 
# !cd /content/yolov3;python detect.py --source /content/yoloss/images/train/2.jpg \
                            --weights /mydrive/ultra_workdir/yoloss/weights/best.pt --conf 0.3 \
                            --project=/content/data/output --name=run_image --exist-ok --line-thickness 3
# Out:
# detect: weights=['/mydrive/ultra_workdir/yoloss/weights/best.pt'], source=/content/yoloss/images/train/2.jpg, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/data/output, name=run_image, exist_ok=True, line_thickness=2, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-3-gb870de5 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.7 GFLOPs
# image 1/1 /content/yoloss/images/train/2.jpg: 640x640 1 Logo, Done. (0.157s)
# Speed: 0.6ms pre-process, 156.6ms inference, 2.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/data/output/run_image

# %%
from IPython.display import Image, clear_output 

Image(filename='/content/data/output/run_image/2.jpg', width=800)

# %%
 # image 파일 inference 
# !cd /content/yolov3;python detect.py --source /content/yoloss/images/train/3.jpg \
                            --weights /mydrive/ultra_workdir/yoloss/weights/best.pt --conf 0.3 \
                            --project=/content/data/output --name=run_image --exist-ok --line-thickness 3
# Out:
# detect: weights=['/mydrive/ultra_workdir/yoloss/weights/best.pt'], source=/content/yoloss/images/train/3.jpg, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/data/output, name=run_image, exist_ok=True, line_thickness=2, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-3-gb870de5 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.7 GFLOPs
# image 1/1 /content/yoloss/images/train/3.jpg: 640x640 3 Logos, Done. (0.140s)
# Speed: 0.6ms pre-process, 139.6ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/data/output/run_image

# %%
from IPython.display import Image, clear_output 

Image(filename='/content/data/output/run_image/3.jpg', width=800)
