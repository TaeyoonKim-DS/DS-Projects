# %% [markdown]
# # Download PyTorch Yolov5 images and labels from Roboflow

# %%
product_id = "767"
image_folder = "{}-6".format(product_id)
print(product_id)
print(image_folder)
# Out:
# 767
# 767-6

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SgaLxwdHL2ih3at97c7N")
project = rf.workspace("logodetection-9ixsl").project("767")
dataset = project.version(6).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to 767-6 in yolov5pytorch:: 100%|██████████| 220/220 [00:00<00:00, 3473.41it/s]

# %%
# !pip install split-folders

# %%
import splitfolders
splitfolders.ratio('767-6/train', output="80201", seed=42, ratio=(.8, 0.19,0.01))
# Out:
# Copying files: 214 files [00:00, 8928.58 files/s]

# %%
#  tar -cvf [압축될 파일명].tar [압축할 폴더나 파일]
# 출처: https://aiden1004.tistory.com/entry/주피터-노트북랩-폴더-한번에-다운로드-받기 [Eternal Moment:티스토리]

# %%
# !tar -cvf 502525split.tar 502525
# Out:
# 502525/
# 502525/train/
# 502525/train/images/
# 502525/train/images/pos--6-_jpg.rf.67a89800c8cebda2f693f683af0016fa.jpg
# 502525/train/images/pos--60-_jpg.rf.d2be89cf8070ca8664a119e2003e844d.jpg
# 502525/train/images/pos--12-_jpg.rf.b12f653242e044e7ac1b693ead9237bc.jpg
# 502525/train/images/pos--107-_jpg.rf.143a480ec2032d11b902a35feb9e88a4.jpg
# 502525/train/images/pos--98-_jpg.rf.8eadc70d1db47c8362428c41091585d4.jpg
# 502525/train/images/pos--49-_jpg.rf.a9e7c256bc7ee09e924a2b0280fc5f49.jpg
# 502525/train/images/pos--10-_jpg.rf.703da4e92b5ca5950848c58edc70bb9f.jpg
# 502525/train/images/pos--67-_jpg.rf.66ffe99d7e75700e2704c80273a8ea9d.jpg
# 502525/train/images/pos--52-_jpg.rf.42cd90c902f503709f1d6890f11afc75.jpg
# 502525/train/images/pos--75-_jpg.rf.ab353b14ecd8338515689be4bf6067f7.jpg
# 502525/train/images/pos--22-_jpg.rf.b6e0e68fcea125b2d4f931e672bb5e09.jpg
# 502525/train/images/pos--29-_jpg.rf.8b7bb10ac12f3db6a080095fc335d8f6.jpg
# ...
