# %%
# !pip install ultralytics

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100%|███████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 101MB/s]
# Ultralytics YOLOv8.0.131 🚀 Python-3.9.13 torch-1.8.1+cu102 CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# ...
# 100%|████████████████████████████████████████| 476k/476k [00:00<00:00, 16.7MB/s]
# image 1/1 /home/studio-lab-user/DS-Projects/yolov8/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 130.4ms
# Speed: 3.4ms preprocess, 130.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/predict

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# %cd /home/studio-lab-user/DS-Projects/yolov8/dataset
# Out:
# /home/studio-lab-user/DS-Projects/yolov8/dataset

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="SgaLxwdHL2ih3at97c7N")
# project = rf.workspace("logodetection-9ixsl").project("13789")
# dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 12.1 MB/s eta 0:00:00
# ...
#   Using cached wget-3.2-py3-none-any.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 21.8 MB/s eta 0:00:00
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 14.2 MB/s eta 0:00:00
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.3
#     Uninstalling idna-3.3:
#       Successfully uninstalled idna-3.3
#   Attempting uninstall: cycler
# ...

# %%
# %cd /home/studio-lab-user/DS-Projects/yolov8/datasets
# Out:
# /home/studio-lab-user/DS-Projects/yolov8/datasets

# %%
# Use the model
model.train(data="data.yaml", epochs=200)  # train the model
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.9.13 torch-1.8.1+cu102 CPU
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
metrics = model.val()  # evaluate model performance on the validation set
# path = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.9.13 torch-1.8.1+cu102 CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /home/studio-lab-user/DS-Projects/yolov8/datasets/valid/labels.cache... 19 images, 0 backgrounds, 0 corrupt: 100%|██████████| 19/19 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.89s/it]
#                    all         19         27          1       0.96      0.991      0.811
# Speed: 2.4ms preprocess, 187.4ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/val

# %%
# !pwd
# Out:
# /home/studio-lab-user/DS-Projects/yolov8/datasets

# %%
results = model("/home/studio-lab-user/DS-Projects/yolov8/datasets/test", save=True, save_txt = True, save_conf = True)  # predict on an image
# Out:
# image 1/1 /home/studio-lab-user/DS-Projects/yolov8/datasets/test/IMG_9810.jpg: 640x480 1 13789, 245.5ms
# Speed: 5.1ms preprocess, 245.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/predict3
# 1 label saved to /home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/predict3/labels

# %%
results
# Out:
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: '13789'}
#  orig_img: array([[[144, 147, 151],
#          [144, 147, 151],
#          [144, 147, 151],
#          ...,
#          [180, 164, 148],
#          [179, 163, 147],
#          [179, 163, 147]],
#
#         [[144, 147, 151],
#          [144, 147, 151],
#          [144, 147, 151],
#          ...,
#          [180, 164, 148],
#          [179, 163, 147],
#          [179, 163, 147]],
#
#         [[144, 147, 151],
#          [144, 147, 151],
#          [144, 147, 151],
#          ...,
#          [180, 164, 148],
#          [180, 164, 148],
#          [180, 164, 148]],
#
#         ...,
#
#         [[154, 193, 225],
#          [154, 193, 225],
#          [154, 193, 225],
#          ...,
#          [133, 109,  79],
#          [133, 109,  79],
#          [133, 109,  79]],
#
# ...

# %%
path = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.9.13 torch-1.8.1+cu102 CPU
#
# PyTorch: starting from /home/studio-lab-user/DS-Projects/yolov8/ultralytics/runs/detect/train4/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# requirements: ❌ AutoUpdate skipped (offline)
# ONNX: export failure ❌ 6.0s: No module named 'onnx'
